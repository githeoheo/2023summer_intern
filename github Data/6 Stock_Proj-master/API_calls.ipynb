# %%
import json
import requests
import time
#import seaborn as sns
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
API_KEY = '1UWE3ZGOK5P1UPGS'

# %%
# set theurl and endpoint we want to hit
#url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MSFT&outputsize=full&apikey=1UWE3ZGOK5P1UPGS'
#url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MSFT&apikey=1UWE3ZGOK5P1UPGS&datatype=csv'

# %%
response = requests.request("GET", url)

# %%
c = response.json()

c
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'MSFT',
#   '3. Last Refreshed': '2019-12-31 10:30:39',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2019-12-31': {'1. open': '156.7700',
#    '2. high': '157.6300',
#    '3. low': '156.4900',
#    '4. close': '156.8600',
#    '5. volume': '2209933'},
#   '2019-12-30': {'1. open': '158.9865',
#    '2. high': '159.0200',
#    '3. low': '156.7300',
#    '4. close': '157.5900',
#    '5. volume': '16263759'},
#   '2019-12-27': {'1. open': '159.4500',
#    '2. high': '159.5500',
#    '3. low': '158.2200',
#    '4. close': '158.9600',
#    '5. volume': '18414352'},
#   '2019-12-26': {'1. open': '157.5511',
#    '2. high': '158.7300',
#    '3. low': '157.4000',
#    '4. close': '158.6700',
#    '5. volume': '14526927'},
#   '2019-12-24': {'1. open': '157.4800',
#    '2. high': '157.7100',
#    '3. low': '157.1150',
# ...

# %%
def parse_data()
    dates = list(c['Time Series (Daily)'].keys())
    data = []
    for d in dates:
        tur = (d, c['Time Series (Daily)'][f'{d}']['1. open'], c['Time Series (Daily)'][f'{d}']['2. high'], 
               c['Time Series (Daily)'][f'{d}']['3. low'], c['Time Series (Daily)'][f'{d}']['4. close'], 
               c['Time Series (Daily)'][f'{d}']['5. volume'])
        data.append(tur)
    data
# Out:
# [('2019-12-31', '156.7700', '157.6300', '156.4900', '156.8600', '2209933'),
#  ('2019-12-30', '158.9865', '159.0200', '156.7300', '157.5900', '16263759'),
#  ('2019-12-27', '159.4500', '159.5500', '158.2200', '158.9600', '18414352'),
#  ('2019-12-26', '157.5511', '158.7300', '157.4000', '158.6700', '14526927'),
#  ('2019-12-24', '157.4800', '157.7100', '157.1150', '157.3800', '8989150'),
#  ('2019-12-23', '158.1200', '158.1200', '157.2700', '157.4100', '17726283'),
#  ('2019-12-20', '157.3500', '158.4900', '156.2900', '157.4100', '53599613'),
#  ('2019-12-19', '154.0000', '155.7700', '153.7500', '155.7100', '25813825'),
#  ('2019-12-18', '154.3000', '155.4800', '154.1800', '154.3700', '24132379'),
#  ('2019-12-17', '155.4500', '155.7100', '154.4500', '154.6900', '25443527'),
#  ('2019-12-16', '155.1100', '155.9000', '154.8200', '155.5300', '24152770'),
#  ('2019-12-13', '153.1106', '154.8900', '152.8300', '154.5300', '23850062'),
# ...

# %%
len(data)
# Out:
# 5034

# %%
fil = pd.read_csv('NASDAQx.csv', index_col=False)
symbols = fil['Ticker']
symbols = list(symbols)
symbols
# Out:
# ['AABA',
#  'AAL',
#  'AAME',
#  'AAOI',
#  'AAON',
#  'AAPL',
#  'AAWW',
#  'AAXJ',
#  'AAXN',
#  'ABAC',
#  'ABAX',
#  'ABCB',
#  'ABCD',
#  'ABDC',
#  'ABEO',
#  'ABEOW',
#  'ABIL',
#  'ABIO',
#  'ABLX',
#  'ABMD',
#  'ABP',
#  'ABTX',
#  'ABUS',
#  'ACAD',
#  'ACBI',
#  'ACER',
#  'ACET',
#  'ACFC',
#  'ACGL',
#  'ACGLO',
#  'ACGLP',
#  'ACHC',
#  'ACHN',
#  'ACHV',
#  'ACIA',
#  'ACIU',
#  'ACIW',
#  'ACLS',
#  'ACMR',
#  'ACNB',
#  'ACOR',
#  'ACRS',
#  'ACRX',
#  'ACSF',
#  'ACST',
#  'ACT',
#  'ACTG',
#  'ACWI',
#  'ACWX',
#  'ACXM',
#  'ADAP',
#  'ADBE',
#  'ADES',
#  'ADI',
#  'ADMA',
#  'ADMP',
#  'ADMS',
#  'ADOM',
#  'ADP',
#  'ADRA',
#  'ADRD',
#  'ADRE',
#  'ADRO',
#  'ADRU',
#  'ADSK',
#  'ADTN',
#  'ADUS',
#  'ADVM',
#  'ADXS',
#  'ADXSW',
#  'AEGN',
#  'AEHR',
#  'AEIS',
#  'AEMD',
#  'AERI',
#  'AETI',
#  'AEY',
#  'AEZS',
#  'AFH',
#  'AFHBL',
#  'AFMD',
#  'AFSI',
#  'AGEN',
#  'AGFS',
#  'AGFSW',
#  'AGIO',
#  'AGLE',
#  'AGMH',
#  'AGNC',
#  'AGNCB',
# ...

# %%
data = []
for s in symbols[0:4]:
    url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={s}&outputsize=full&apikey=1UWE3ZGOK5P1UPGS'
    response = requests.request("GET", url)
    c = response.json()
    dates = list(c['Time Series (Daily)'].keys())
    data1 = []
    for d in dates:
        tur = (s, d, c['Time Series (Daily)'][f'{d}']['1. open'], c['Time Series (Daily)'][f'{d}']['2. high'], 
               c['Time Series (Daily)'][f'{d}']['3. low'], c['Time Series (Daily)'][f'{d}']['4. close'], 
               c['Time Series (Daily)'][f'{d}']['5. volume'])
        data1.append(tur)
    data.extend(data1)
data[-10]
# Out:
# ('AAOI', '2013-10-09', '10.1400', '10.2100', '10.1400', '10.1500', '14800')

# %%
data[0]
# Out:
# ('AABA', '2019-11-06', '19.6300', '19.6300', '19.6300', '19.6300', '97474')

# %%
cd /Users/flatironschool/Documents/Stock_Proj
# Out:
# /Users/flatironschool/Documents/Stock_Proj

# %%
import os

response1 = requests.get(url)
with open(os.path.join("/Users/flatironschool/Documents", "csvfile.csv"), 'wb') as f:
    f.write(response1.content)

# %%
pwd
# Out:
# '/Users/flatironschool/Documents'

# %%
fil = pd.read_csv('csvfile.csv')
#fil = pd.DataFrame('csvfile.csv')
#movies = pd.read_csv('IMDB-Movie-Data.csv')
fil
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-47-328fce7ee5eb> in <module>
# ----> 1 fil = pd.read_csv('csvfile.csv')
#       2 #fil = pd.DataFrame('csvfile.csv')
#       3 #movies = pd.read_csv('IMDB-Movie-Data.csv')
#       4 fil
#
# ...
